# %%
from lightgbm import LGBMClassifier

import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from lightgbm import plot_importance
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/최종데이터.csv', index_col=0)

# %%
df.head(3)
# Out:
#          date  tesla  tesla_거래량  tesla_volatility  elec_fee  oli_price  \
# 0  2015-01-02  43.86    23820.0             -1.39      6.67      52.69
# 1  2015-01-05  42.02    26840.0             -4.20      6.67      50.04
# 2  2015-01-06  42.26    31310.0              0.57      6.67      47.93
#
#    oli_price_volatility  carbon_credits  carbon_credits_volatility  EVE종가  \
# 0                 -3.44            7.01                      -3.31  13.38
# 1                 -5.03            6.90                      -1.57  13.38
# 2                 -4.22            6.77                      -1.88  13.89
#
#    ...  alu_price  alu_vol  alu_change  cu_price  cu_change  REGI_price  \
# 0  ...    1828.00    31.38       -1.12   6250.25      -0.55        9.79
# 1  ...    1812.25    43.25       -0.86   6142.00      -1.73        9.55
# 2  ...    1780.25    56.01       -1.77   6131.00      -0.18        9.12
#
#    REGI_vol  REGI_change  검색량  updown
# 0    436.60         0.82   22       0
# 1    481.67        -2.45   19       0
# 2    534.76        -4.50   23       1
#
# [3 rows x 47 columns]

# %%
y = df.updown
x = df.drop(['date', 'tesla', 'tesla_volatility', 'updown'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=156)
lgbm_wrapper = LGBMClassifier(n_estimators=400)
evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss', eval_set=evals, verbose=True)
pred = lgbm_wrapper.predict(X_test)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:1]
CO.get_clf_eval(y_test, pred)

fig, ax = plt.subplots(figsize=(10,12))
plot_importance(lgbm_wrapper, ax=ax)
plt.show()
# Out:
# [1]	valid_0's binary_logloss: 0.67541
# [2]	valid_0's binary_logloss: 0.668619
# [3]	valid_0's binary_logloss: 0.661857
# [4]	valid_0's binary_logloss: 0.655617
# [5]	valid_0's binary_logloss: 0.649567
# [6]	valid_0's binary_logloss: 0.646425
# [7]	valid_0's binary_logloss: 0.642969
# [8]	valid_0's binary_logloss: 0.641144
# [9]	valid_0's binary_logloss: 0.642348
# [10]	valid_0's binary_logloss: 0.639786
# [11]	valid_0's binary_logloss: 0.637688
# [12]	valid_0's binary_logloss: 0.637627
# [13]	valid_0's binary_logloss: 0.637173
# [14]	valid_0's binary_logloss: 0.638482
# [15]	valid_0's binary_logloss: 0.63747
# [16]	valid_0's binary_logloss: 0.637479
# [17]	valid_0's binary_logloss: 0.637953
# [18]	valid_0's binary_logloss: 0.639982
# [19]	valid_0's binary_logloss: 0.642794
# [20]	valid_0's binary_logloss: 0.643673
# [21]	valid_0's binary_logloss: 0.641533
# [22]	valid_0's binary_logloss: 0.644391
# [23]	valid_0's binary_logloss: 0.643477
# [24]	valid_0's binary_logloss: 0.645513
# [25]	valid_0's binary_logloss: 0.643949
# [26]	valid_0's binary_logloss: 0.643323
# [27]	valid_0's binary_logloss: 0.6449
# [28]	valid_0's binary_logloss: 0.644502
# [29]	valid_0's binary_logloss: 0.643314
# [30]	valid_0's binary_logloss: 0.646482
# [31]	valid_0's binary_logloss: 0.644008
# [32]	valid_0's binary_logloss: 0.644471
# [33]	valid_0's binary_logloss: 0.647821
# [34]	valid_0's binary_logloss: 0.648048
# [35]	valid_0's binary_logloss: 0.647932
# [36]	valid_0's binary_logloss: 0.647003
# [37]	valid_0's binary_logloss: 0.649427
# [38]	valid_0's binary_logloss: 0.648669
# [39]	valid_0's binary_logloss: 0.648047
# [40]	valid_0's binary_logloss: 0.647634
# [41]	valid_0's binary_logloss: 0.65046
# [42]	valid_0's binary_logloss: 0.650776
# [43]	valid_0's binary_logloss: 0.649925
# [44]	valid_0's binary_logloss: 0.650345
# [45]	valid_0's binary_logloss: 0.651425
# [46]	valid_0's binary_logloss: 0.652681
# [47]	valid_0's binary_logloss: 0.653905
# [48]	valid_0's binary_logloss: 0.654181
# [49]	valid_0's binary_logloss: 0.654691
# [50]	valid_0's binary_logloss: 0.65478
# [51]	valid_0's binary_logloss: 0.655044
# [52]	valid_0's binary_logloss: 0.658694
# [53]	valid_0's binary_logloss: 0.660088
# [54]	valid_0's binary_logloss: 0.66314
# [55]	valid_0's binary_logloss: 0.664152
# [56]	valid_0's binary_logloss: 0.666186
# [57]	valid_0's binary_logloss: 0.669351
# [58]	valid_0's binary_logloss: 0.671348
# [59]	valid_0's binary_logloss: 0.672684
# [60]	valid_0's binary_logloss: 0.673449
# [61]	valid_0's binary_logloss: 0.676776
# [62]	valid_0's binary_logloss: 0.676787
# [63]	valid_0's binary_logloss: 0.677453
# [64]	valid_0's binary_logloss: 0.681122
# [65]	valid_0's binary_logloss: 0.681368
# [66]	valid_0's binary_logloss: 0.682412
# [67]	valid_0's binary_logloss: 0.682548
# [68]	valid_0's binary_logloss: 0.685646
# [69]	valid_0's binary_logloss: 0.688701
# [70]	valid_0's binary_logloss: 0.688589
# [71]	valid_0's binary_logloss: 0.692555
# [72]	valid_0's binary_logloss: 0.693722
# [73]	valid_0's binary_logloss: 0.694408
# [74]	valid_0's binary_logloss: 0.698284
# [75]	valid_0's binary_logloss: 0.703607
# [76]	valid_0's binary_logloss: 0.704931
# [77]	valid_0's binary_logloss: 0.705364
# [78]	valid_0's binary_logloss: 0.707405
# [79]	valid_0's binary_logloss: 0.70707
# [80]	valid_0's binary_logloss: 0.711344
# [81]	valid_0's binary_logloss: 0.71455
# [82]	valid_0's binary_logloss: 0.71735
# [83]	valid_0's binary_logloss: 0.716251
# [84]	valid_0's binary_logloss: 0.717067
# [85]	valid_0's binary_logloss: 0.718188
# [86]	valid_0's binary_logloss: 0.718475
# [87]	valid_0's binary_logloss: 0.722269
# [88]	valid_0's binary_logloss: 0.722764
# [89]	valid_0's binary_logloss: 0.7248
# [90]	valid_0's binary_logloss: 0.726379
# [91]	valid_0's binary_logloss: 0.727647
# [92]	valid_0's binary_logloss: 0.72797
# [93]	valid_0's binary_logloss: 0.728449
# [94]	valid_0's binary_logloss: 0.730962
# [95]	valid_0's binary_logloss: 0.734204
# [96]	valid_0's binary_logloss: 0.734533
# [97]	valid_0's binary_logloss: 0.73261
# [98]	valid_0's binary_logloss: 0.73529
# [99]	valid_0's binary_logloss: 0.737356
# [100]	valid_0's binary_logloss: 0.737007
# [101]	valid_0's binary_logloss: 0.737226
# [102]	valid_0's binary_logloss: 0.737944
# [103]	valid_0's binary_logloss: 0.739346
# [104]	valid_0's binary_logloss: 0.740941
# [105]	valid_0's binary_logloss: 0.741766
# [106]	valid_0's binary_logloss: 0.742289
# [107]	valid_0's binary_logloss: 0.742465
# [108]	valid_0's binary_logloss: 0.741058
# [109]	valid_0's binary_logloss: 0.741539
# [110]	valid_0's binary_logloss: 0.744827
# [111]	valid_0's binary_logloss: 0.746465
# [112]	valid_0's binary_logloss: 0.748649
# [113]	valid_0's binary_logloss: 0.747749
# C:\Users\bitcamp\anaconda3\lib\site-packages\lightgbm\sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\bitcamp\anaconda3\lib\site-packages\lightgbm\sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10204/249818850.py in <module>
#       8 pred = lgbm_wrapper.predict(X_test)
#       9 pred_proba = lgbm_wrapper.predict_proba(X_test)[:1]
# ---> 10 CO.get_clf_eval(y_test, pred)
#      11
#      12 fig, ax = plt.subplots(figsize=(10,12))
#
# NameError: name 'CO' is not defined

# %%
# 평가지표 출력하는 함수 설정
def get_clf_eval(y_test, y_pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred)
    AUC = roc_auc_score(y_test, y_pred, pred_proba)

    print('오차행렬:\n', confusion)
    print('\n정확도: {:.4f}'.format(accuracy))
    print('정밀도: {:.4f}'.format(precision))
    print('재현율: {:.4f}'.format(recall))
    print('F1: {:.4f}'.format(F1))
    print('AUC: {:.4f}'.format(AUC))
